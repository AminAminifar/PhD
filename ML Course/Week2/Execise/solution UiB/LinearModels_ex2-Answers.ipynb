# %% [markdown]
# # 1.Univariate Regression
# In this part you have to first we try and implement the building blocks for a linear regression implementation. First of all, we need to make sure to have the necessary libraries installed.

# %%
# install numpy and pandas first. If you have them installed already then pip won't install them
# and you will get requirement already satisfied message. That's normal.
# !pip install numpy
# !pip install pandas
import numpy as np
import pandas as pd
np.random.seed(2)
# Out:
# Requirement already satisfied: numpy in /anaconda3/lib/python3.7/site-packages (1.16.2)
# Requirement already satisfied: pandas in /anaconda3/lib/python3.7/site-packages (0.24.2)
# Requirement already satisfied: pytz>=2011k in /anaconda3/lib/python3.7/site-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.12.0 in /anaconda3/lib/python3.7/site-packages (from pandas) (1.16.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /anaconda3/lib/python3.7/site-packages (from pandas) (2.8.0)
# Requirement already satisfied: six>=1.5 in /anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas) (1.12.0)

# %% [markdown]
# Now let's load some points from the  "unilinear.csv" file:

# %%
# Read the X and y values from unilinear.csv
datapoints = np.genfromtxt('unilinear.csv', delimiter=',')
X = datapoints[:,0]
X = X.reshape(-1,1)
X.sort(axis=0)


y = datapoints[:,1]
y = y.reshape(-1,1)

# let us plot the data
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(X, y)
plt.grid()

# %% [markdown]
# ## Exercise 1.1
# Implement the closed form of linear regression which was taught in the lecture:
# ##### Hints:
# 1. Add a column of 1's to X using `np.hstack`. This column of 1's models for the y-intercept ($w_0$).
# 2. Use `inv` function in numpy to find the inverse of a matrix. inv is defined in `numpy.linalg` module so will need to import it from it.
# 3. To multiply two matrices `a` and `b`, use the following notation in python `a.dot(b)`
# 4. To transpose a matrix `c` use `c.T`

# %%
# TODO
# Write your solution here
from numpy.linalg import inv
one = np.ones([100,1])
X_tmp = np.hstack((one,X))
w_hat = inv(X_tmp.T.dot(X_tmp)).dot(X_tmp.T).dot(y)

# %%
# TODO
# Check the values of w_hat vector
w_hat
# Out:
# array([[6.45478709],
#        [5.02129039]])

# %%
# TODO
# plot the estimated line with datapoints showing 
xplt = np.linspace(0,2,100)
yplt = w_hat[0] + w_hat[1]*xplt
plt.plot(xplt,yplt,'r')
plt.scatter(X, y)
plt.grid()

# %% [markdown]
# ## Exercise 1.2
# ### Implementation of Gradient Descent
# Calculate the loss function of Mean Square Error (MSE):

# %%
def loss_function(X, y, w0, w1):
    # TODO
    # calculate the sum of squared errors for the current W vector
    totalError = 0
    for i in range(0, len(X)):
        totalError += (y[i] - (w1 * X[i] + w0)) ** 2
    # find mean of sum of squared errors    
    mse = totalError/len(X)
    return mse

# %% [markdown]
# Next you need to evaluate the current function with respect to w0 and w1. In order to do that caculate the one step derivatives of the MSE with respect to w0 and w1:

# %%
def compute_gradient(X, y, w0, w1):
    # TODO
    # calculate the gradient vector of partial derivatives of MSE with the formulat that you have found
    w0_par_der = 0
    w1_par_der = 0
    n = len(X)
    for i in range(0, len(X)):
        # partial derivative (of MSE) with respect to w0
        w0_par_der += (y[i] - ((w1 * X[i]) + w0))
        # partial derivative (of MSE) with respect to w1
        w1_par_der += X[i] * (y[i] - ((w1 * X[i]) + w0))
    # multiplcation of summation results with -2/n
    w0_par_der = -(2/n) * w0_par_der
    w1_par_der = -(2/n) * w1_par_der
    # make a gradient vector from the partial derivatives    
    gradient_mse = np.array([w0_par_der, w1_par_der])
    return gradient_mse

# %% [markdown]
# Now you need to update your $w_0$ and $w_1$ using a certain learning rate:

# %%
def update_parameters(w0, w1, w0_par_der, w1_par_der, learning_rate):
    
    # make a vector of weights
    weight_vector = np.array([w0, w1])
    # make a gradient vector from the partial derivatives    
    gradient_mse = np.array([w0_par_der, w1_par_der])
    # TODO
    # update the vector of W (w0,w1) using the update rule and return the value of updated weights
    updated_weight_vector = weight_vector - (learning_rate * gradient_mse)
    # return the updated weight vector as a list
    return np.ndarray.tolist(updated_weight_vector)

# %% [markdown]
# The next step is to run multiple iterations of gradient descent:

# %%
def run_optimization(X, y, starting_w0, starting_w1, learning_rate, num_iterations):
    w0 = starting_w0
    w1 = starting_w1
    # TODO
    for i in range(num_iterations):
        gradient_mse = compute_gradient(X, y, w0, w1)
        w0, w1 = update_parameters(w0, w1, gradient_mse[0], gradient_mse[1], learning_rate)
        mse = loss_function(X, y, w0, w1)
        print(f'Iteration {i+1}: w0={w0:0.5f}, w1={w1:0.5f}, mse={mse:0.5f}')
    return [w0, w1, mse]

# %% [markdown]
# Now to test your implementation :

# %%
X = X.flatten()
y = y.flatten()
num_iterations = 40
learning_rate = 0.1
starting_w0 = 0 # initial y-intercept guess
starting_w1 = 0 # initial slope guess

[w0,w1,_] = run_optimization(X, y, starting_w0, starting_w1, learning_rate, num_iterations)
# Out:
# Iteration 1: w0=2.21493, w1=2.32156, mse=47.34810
# Iteration 2: w0=3.55968, w1=3.71134, mse=17.37766
# Iteration 3: w0=4.37975, w1=4.53985, mse=6.48588
# Iteration 4: w0=4.88335, w1=5.03039, mse=2.52335
# Iteration 5: w0=5.19596, w1=5.31750, mse=1.07772
# Iteration 6: w0=5.39322, w1=5.48225, mse=0.54653
# Iteration 7: w0=5.52071, w1=5.57351, mse=0.34778
# Iteration 8: w0=5.60591, w1=5.62070, mse=0.27009
# Iteration 9: w0=5.66539, w1=5.64156, mse=0.23667
# Iteration 10: w0=5.70913, w1=5.64676, mse=0.21963
# Iteration 11: w0=5.74317, w1=5.64274, mse=0.20881
# Iteration 12: w0=5.77114, w1=5.63336, mse=0.20051
# Iteration 13: w0=5.79524, w1=5.62095, mse=0.19336
# Iteration 14: w0=5.81681, w1=5.60691, mse=0.18687
# Iteration 15: w0=5.83664, w1=5.59208, mse=0.18084
# Iteration 16: w0=5.85524, w1=5.57694, mse=0.17517
# Iteration 17: w0=5.87290, w1=5.56180, mse=0.16984
# Iteration 18: w0=5.88982, w1=5.54683, mse=0.16481
# Iteration 19: w0=5.90611, w1=5.53212, mse=0.16006
# Iteration 20: w0=5.92185, w1=5.51774, mse=0.15558
# Iteration 21: w0=5.93708, w1=5.50371, mse=0.15135
# Iteration 22: w0=5.95185, w1=5.49004, mse=0.14736
# Iteration 23: w0=5.96618, w1=5.47674, mse=0.14359
# Iteration 24: w0=5.98010, w1=5.46381, mse=0.14004
# Iteration 25: w0=5.99361, w1=5.45124, mse=0.13668
# Iteration 26: w0=6.00673, w1=5.43902, mse=0.13351
# Iteration 27: w0=6.01947, w1=5.42714, mse=0.13052
# Iteration 28: w0=6.03185, w1=5.41561, mse=0.12769
# Iteration 29: w0=6.04388, w1=5.40439, mse=0.12503
# Iteration 30: w0=6.05557, w1=5.39350, mse=0.12251
# Iteration 31: w0=6.06692, w1=5.38292, mse=0.12014
# Iteration 32: w0=6.07795, w1=5.37263, mse=0.11790
# Iteration 33: w0=6.08867, w1=5.36264, mse=0.11578
# Iteration 34: w0=6.09908, w1=5.35294, mse=0.11378
# Iteration 35: w0=6.10919, w1=5.34351, mse=0.11190
# Iteration 36: w0=6.11902, w1=5.33434, mse=0.11012
# Iteration 37: w0=6.12857, w1=5.32544, mse=0.10844
# Iteration 38: w0=6.13784, w1=5.31679, mse=0.10685
# Iteration 39: w0=6.14686, w1=5.30839, mse=0.10536
# Iteration 40: w0=6.15561, w1=5.30022, mse=0.10394

# %% [markdown]
# Test it again with learning rate of 1:

# %%
X = X.flatten()
y = y.flatten()
num_iterations = 40
learning_rate = 1
starting_w0 = 0 # initial y-intercept guess
starting_w1 = 0 # initial slope guess

w0_prime,w1_prime,_ = run_optimization(X, y, starting_w0, starting_w1, learning_rate, num_iterations)
# Out:
# Iteration 1: w0=22.14932, w1=23.21556, mse=1145.57670
# Iteration 2: w0=-42.71926, w1=-46.74664, mse=10128.04447
# Iteration 3: w0=150.88767, w1=160.63065, mse=89555.47553
# Iteration 4: w0=-424.31690, w1=-456.50662, mse=791888.03243
# Iteration 5: w0=1286.48998, w1=1378.28758, mse=7002221.73248
# Iteration 6: w0=-3800.54553, w1=-4077.94397, mse=61916725.58570
# Iteration 7: w0=11326.57248, w1=12146.66334, mse=547494936.94083
# Iteration 8: w0=-33655.65605, w1=-36099.34411, mse=4841191188.06990
# Iteration 9: w0=100104.67708, w1=107366.05570, mse=42807943125.80426
# Iteration 10: w0=-297648.20061, w1=-319246.17412, mse=378526673187.83038
# Iteration 11: w0=885119.37920, w1=949338.17515, mse=3347099436517.65381
# Iteration 12: w0=-2631986.72972, w1=-2822954.81277, mse=29596526299163.96094
# Iteration 13: w0=7826564.67594, w1=8394426.39002, mse=261705511171927.12500
# Iteration 14: w0=-23273235.49838, w1=-24961848.36840, mse=2314115308177042.50000
# Iteration 15: w0=69205878.87034, w1=74227173.11104, mse=20462426012959604.00000
# Iteration 16: w0=-205792241.53592, w1=-220723688.60170, mse=180937776460969888.00000
# Iteration 17: w0=611948788.38565, w1=656349293.10915, mse=1599931451427382528.00000
# Iteration 18: w0=-1819705620.82495, w1=-1951736036.04321, mse=14147298034353278976.00000
# Iteration 19: w0=5411120459.18069, w1=5803729274.10370, mse=125096635542888562688.00000
# Iteration 20: w0=-16090638014.89172, w1=-17258109042.54005, mse=1106159507359643729920.00000
# Iteration 21: w0=47847508520.78714, w1=51319128463.39094, mse=9781149192478737301504.00000
# Iteration 22: w0=-142280502978.70807, w1=-152603795605.97781, mse=86489225910908386017280.00000
# Iteration 23: w0=423088728307.66864, w1=453786319735.20618, mse=764775800007245449658368.00000
# Iteration 24: w0=-1258106826015.98535, w1=-1349389922767.13721, mse=6762484206751982217592832.00000
# Iteration 25: w0=3741136739904.13086, w1=4012578353538.70557, mse=59796861571896996024811520.00000
# Iteration 26: w0=-11124734257148.39648, w1=-11931899572929.36719, mse=528750167028633273588776960.00000
# Iteration 27: w0=33080777554183.69531, w1=35480983765272.36719, mse=4675441683451193189673730048.00000
# Iteration 28: w0=-98369796373793.28125, w1=-105507107334922.43750, mse=41342313059107029163320541184.00000
# Iteration 29: w0=292514794211695.37500, w1=313738473877408.93750, mse=365566927104857332415427772416.00000
# Iteration 30: w0=-869829032760871.37500, w1=-932940277458793.00000, mse=3232503657979280540727588683776.00000
# Iteration 31: w0=2586544548191923.00000, w1=2774213664483522.50000, mse=28583219990938255912352121618432.00000
# Iteration 32: w0=-7691411125409637.00000, w1=-8249468526721372.00000, mse=252745410831522327856728017731584.00000
# Iteration 33: w0=22871365251152788.00000, w1=24530818171871528.00000, mse=2234886157565417650260998484918272.00000
# Iteration 34: w0=-68010842213791872.00000, w1=-72945431361089536.00000, mse=19761846993957682885232859172306944.00000
# Iteration 35: w0=202238677395795488.00000, w1=216912290457430976.00000, mse=174742948445311511254070362051182592.00000
# Iteration 36: w0=-601381798893625216.00000, w1=-645015607880643072.00000, mse=1545154055726526597218597455586656256.00000
# Iteration 37: w0=1788283392166068224.00000, w1=1918033936815049216.00000, mse=13662932193657822038043245691642314752.00000
# Iteration 38: w0=-5317682538082018304.00000, w1=-5703511880684576768.00000, mse=120813659606722435317413440210945966080.00000
# Iteration 39: w0=15812788789348884480.00000, w1=16960100209241989120.00000, mse=1068287549164905560662798246756501946368.00000
# Iteration 40: w0=-47021289350368772096.00000, w1=-50432962203807088640.00000, mse=9446268670411658537508864182003265699840.00000

# %% [markdown]
# Compare your results with the sklearn version of linear regression:

# %%
# install sklearn if it isn't installed already 
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /anaconda3/lib/python3.7/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /anaconda3/lib/python3.7/site-packages (from sklearn) (0.20.3)
# Requirement already satisfied: numpy>=1.8.2 in /anaconda3/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.16.2)
# Requirement already satisfied: scipy>=0.13.3 in /anaconda3/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.2.1)

# %%
# import LinearRegression class from sklearn.linear_model module
from sklearn.linear_model import LinearRegression

# make a lin_reg object form the LinearRegression class
lin_reg = LinearRegression()
X = np.reshape(X,(100,1))
y = np.reshape(y,(100,1))
lin_reg.fit(X, y)
print('y-intercept w1:', lin_reg.intercept_)
print('slope w0:', lin_reg.coef_)
# Out:
# y-intercept w1: [6.45478709]
# slope w0: [[5.02129039]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# plot the original data points as a scatter plot
plt.scatter(X, y, label='original data')

# plot the line that fits these points. Use the values of m and b as provided by the fit method
y_ = lin_reg.coef_*X + lin_reg.intercept_
y_GD = w1*X + w0
# you can also get y_ by using the predict method. Uncomment the line below:
#y_ = lin_reg.predict(X)

plt.plot(X, y_, color='r', label='sklearn predicted fit')
plt.plot(X, y_GD, color='b', label='GD predicted fit')
plt.xlabel('X'); plt.ylabel('y')
plt.grid
plt.legend(loc='best')

# %% [markdown]
# # 2.Multivariate Regression
#
# In this part we will try to work with more complicated datasets. In order to import datasets into your models first we need to use pandas library for python:

# %%
import pandas as pd

# make a dataframe of the data
df = pd.read_csv('Psychology grades.csv')

# show first five rows of df
df.head(n=5)
# Out:
#    EXAM1  EXAM2  EXAM3  FINAL
# 0     73     80     75    152
# 1     93     88     93    185
# 2     89     91     90    180
# 3     96     98    100    196
# 4     73     66     70    142

# %% [markdown]
# Next we need to seperate features and labels:

# %%
# Extract the last column and set it to the output or dependent varaible y
y = df[['FINAL']]

# Remove the first column and set the rest of the dataframe to X. This is the set of indepedent variables
X = df.drop(columns=['FINAL'])

# show first five rows of X
X.head(n=5)
# Out:
#    EXAM1  EXAM2  EXAM3
# 0     73     80     75
# 1     93     88     93
# 2     89     91     90
# 3     96     98    100
# 4     73     66     70

# %%
# show first five rows of y
y.head(n=5)
# Out:
#    FINAL
# 0    152
# 1    185
# 2    180
# 3    196
# 4    142

# %% [markdown]
# ## Exercise 2.1
# Now fit a Multivariate Linear Regression model to it.

# %% [markdown]
# ##### Hint:
# Use LinearRegression from sklearn in order to fit the model.

# %%
# TODO
# fit a linear regression using sklearn. LinearRegression to the exam dataset and show the values of intercept_ and coef_

# make a lin_reg object form the LinearRegression class
lin_reg = LinearRegression()

# use the fit method of LinearRegression class to fit a straight line through the data
lin_reg.fit(X, y)

# Display the learned parameters
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([-4.3361024]), array([[0.35593822, 0.54251876, 1.16744422]]))

# %% [markdown]
# find out the grade for 50, 60 and 70 in exams:

# %%
# TODO
# use the predict method 
lin_reg.predict([[50,60,70]])
# Out:
# array([[127.73302913]])

# %% [markdown]
# ## Exercise 2.2
# Now load the datapoints from "nonlinear.csv" and "nonlinear_val.csv" file:

# %%
import numpy as np
import matplotlib.pyplot as plt

datapoints = np.genfromtxt('nonlinear.csv', delimiter=',')
datapoints_val = np.genfromtxt('nonlinear_val.csv', delimiter=',')

X = datapoints[:,0]
X = X.reshape(-1,1)
X.sort(axis=0)


y = datapoints[:,1]
y = y.reshape(-1,1)




X_val = datapoints_val[:,0]
X_val = X_val.reshape(-1,1)
X_val.sort(axis =0)

y_val = datapoints_val[:,1]
y_val = y_val.reshape(-1,1)
# plot it
fig , (ax1,ax2) = plt.subplots(2,figsize=(8, 8), dpi=80)

ax1.scatter(X,y)
ax2.scatter(X_val,y_val)

# %% [markdown]
# Fit a normal linear regression to both training and validation sets:

# %%
from sklearn.metrics import mean_squared_error
# make a lin_reg object form the LinearRegression class
lin_reg = LinearRegression()

# use the fit method of LinearRegression class to fit a straight line through the data
lin_reg.fit(X, y)

y_=lin_reg.predict(X)
y_val_ = lin_reg.predict(X_val)
fig , (ax1,ax2) = plt.subplots(2,figsize=(8, 8), dpi=80)
print(mean_squared_error(y,y_))
print(mean_squared_error(y_val,y_val_))
ax1.scatter(X,y)
ax2.scatter(X_val,y_val)

ax1.plot(X,y_,color='r')
ax2.plot(X,y_,color='r')
# Out:
# 62.55930084175355
# 82.28700425007989

# %% [markdown]
# Now define an RBF function as your basis function

# %%
def RBF(X,C,eps):
    return np.exp((-(X-C)**2)/(eps))

# %% [markdown]
# Transform datapoints according to the RBF functions with centers at (-5,-5.5,-4,...,4.5,5) with epsilon of 0.1 to a 12-dimensional space:

# %%
X_RBF=RBF(X,-5,0.1)
for i in np.arange(-4,6,1):
    X_RBF=np.hstack((X_RBF,RBF(X,i,0.1)))

X_RBF_val = RBF(X_val,-5,0.1)
for i in np.arange(-4,6,1):
    X_RBF_val=np.hstack((X_RBF_val,RBF(X_val,i,0.1)))
    
x_grid = np.linspace(-5, 4.5, 1000)
x_grid = x_grid.reshape(-1,1)
X_RBF_grid = RBF(x_grid,-5,0.1)
for i in np.arange(-4,6,1):
    X_RBF_grid=np.hstack((X_RBF_grid,RBF(x_grid,i,0.1)))

# %% [markdown]
# check the dimension of the new datasets:

# %%
print(X_RBF.shape)
print(X_RBF_val.shape)
print(X_RBF_grid.shape)
# Out:
# (100, 11)
# (20, 11)
# (1000, 11)

# %% [markdown]
# Try to fit a linear regression on the new X_RBF:

# %%
from sklearn.metrics.pairwise import rbf_kernel 
from sklearn.linear_model import LinearRegression

# find the transformation of X using Radial Basis Functions 


# Fit a linear regression model to the RBF-transformed data
clf = LinearRegression()
clf.fit(X_RBF, y)

# find the predicted values
y_= clf.predict(X_RBF)
y_val_=clf.predict(X_RBF_val)
y_grid = clf.predict(X_RBF_grid)
print(mean_squared_error(y,y_))
print(mean_squared_error(y_val,y_val_))
fig , (ax1,ax2) = plt.subplots(2,figsize=(8, 8), dpi=80)
ax1.plot(X, y_, color='r', label='Fitted for RBF-transformed on training data')
ax2.plot(X, y_, color='r', label='Fitted for RBF-transformed on validation data')

ax1.scatter(X,y)
ax2.scatter(X_val,y_val)


ax1.legend(loc='best')
ax2.legend(loc='best')
# Out:
# 22.674391620742497
# 23.76344243393485

# %% [markdown]
# Now repeat the same procedure but this time put your centers at (-5,-4.9,-4.8,...,4.8,4.9). (your new space should have 74 dimensions)

# %%
X_RBF_2=RBF(X,-5,0.1)
for i in np.arange(-4.9,5,0.1):
    X_RBF_2=np.hstack((X_RBF_2,RBF(X,i,0.1)))
    
X_RBF_val_2 = RBF(X_val,-5,0.1)
for i in np.arange(-4.9,5,0.1):
    X_RBF_val_2=np.hstack((X_RBF_val_2,RBF(X_val,i,0.1)))
    
x_grid = np.linspace(-5, 4.5, 1000)
x_grid = x_grid.reshape(-1,1)
X_RBF_grid = RBF(x_grid,-5,0.1)
for i in np.arange(-4.9,5,0.1):
    X_RBF_grid=np.hstack((X_RBF_grid,RBF(x_grid,i,0.1)))

# %%
print (X_RBF_2.shape)
print (X_RBF_val_2.shape)
print (X_RBF_grid.shape)
# Out:
# (100, 100)
# (20, 100)
# (1000, 100)

# %%
clf2 = LinearRegression()
clf2.fit(X_RBF_2, y)

#x_grid=x_grid.reshape(-1,1)
y2_ = clf2.predict(X_RBF_2)
y2grid_ = clf2.predict(X_RBF_grid)
y2_val_=clf2.predict(X_RBF_val_2)#clf2.predict(X_RBF_val_2)


fig , (ax1,ax2) = plt.subplots(2,figsize=(8, 8), dpi=80)
print(mean_squared_error(y,y2_))
print(mean_squared_error(y_val,y2_val_))
ax1.plot(x_grid, y2grid_, color='r', label='Fitted for RBF-transformed on training data')
ax2.plot(x_grid, y2grid_, color='r', label='Fitted for RBF-transformed on validation data')

ax1.scatter(X,y)
ax2.scatter(X_val,y_val)


ax1.legend(loc='best')
ax2.legend(loc='best')
# Out:
# 0.03426236957687441
# 570029014247768.0

# %% [markdown]
# In order to solve overfitting use the Ridge regularization. plot the resulting fit and compare it with the last one.
# ##### Hint:
# Use the `Ridge` from  `sklearn.linear_model` with `alpha=1`

# %%
from sklearn.linear_model import Ridge

# Create Ridge regression object from Ridge class
ridge_reg = Ridge(alpha=1)
# Fit data using Ridge regression
ridge_reg.fit(X_RBF_2, y)

yRidge_ = ridge_reg.predict(X_RBF_2)
yRidge_val_ = ridge_reg.predict(X_RBF_val_2)
yRidge_grid_ = ridge_reg.predict(X_RBF_grid)
# plot original data and predicted fit
print(mean_squared_error(y,yRidge_))
print(mean_squared_error(y_val,yRidge_val_))
fig , (ax1,ax2) = plt.subplots(2,figsize=(8, 8), dpi=80)
ax1.scatter(X, y, label='Original data')
#ax1.plot(x_grid, y2_, color='r', label='Fit for RBF-transformed data')
ax1.plot(x_grid, yRidge_grid_, color='b', label='Fit for Ridge_RBF-transformed data')

ax2.scatter(X_val, y_val, label='Original data')
#ax2.plot(x_grid, y2_val_, color='r', label='Fit for RBF-transformed data')
ax2.plot(x_grid, yRidge_grid_, color='b', label='Fit for Ridge_RBF-transformed data')

ax1.legend(loc='best')
ax2.legend(loc='best')
# Out:
# 5.583132917278019
# 9.710038521599483

# %% [markdown]
# # 3. Logistic Regression

# %% [markdown]
# First we need to load a dataset.

# %%
from sklearn import datasets
iris = datasets.load_iris()

# iris is a dictionary of key-value pairs. Each key-value pairs contains some information about the dataset.
# Lets display a list of these keys and see what they hold
list(iris.keys())
# Out:
# ['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename']

# %% [markdown]
# - `data`: holds the data of sepal and petal lengths and widths in four columns,
# - `target`: holds the class of each flower. These class are encoded as 0, 1, and 2,
# - `target_names`: holds the names of each of the flower classes,
# - `DESCR`: contains a detailed description of the dataset, and
# - `feature_names`: contains a list of name of the columns of data

# %% [markdown]
# load the petal width of the Iris-Versicolor and plot the data according to the labels of 1 and 0 (1 if Iris-Virginica, else 0)

# %%
# let us get the petal width. It is present in the 4th column of data
import numpy as np
X = iris["data"][:, 3] 
X = X.reshape(-1,1)
X.sort(axis=0)

# lets define a binaray variable that encodes whether a flower is Iris-Versicolor or not
# Iris_virginca flower is encoded as a 2 in target  
y = (iris["target"] == 2).astype(np.int) # 1 if Iris-Versicolor, else 0

# %%
import matplotlib.pyplot as plt
plt.scatter(X, y)
plt.xlabel('Petal width (cm)')
plt.ylabel('Iris-Versicolor(1) \n Not Iris-Versicolor(0)')
# Out:
# Text(0, 0.5, 'Iris-Versicolor(1) \n Not Iris-Versicolor(0)')

# %% [markdown]
# Fit a linear regression model to the Iris pedal width for Iris-Versicolor and plot the results.

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
y_ = lin_reg.predict(X)

plt.scatter(X, y, label='original data')
plt.plot(X, y_, color='r', label='fit from linear regression')
plt.legend(loc='best')
plt.grid()

# %% [markdown]
# Now fit a logistic regression to the same feature and compare the results to the linear regression in a plot.

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X, y)
X_new = np.linspace(0, 3, 1000).reshape(-1, 1)
y_proba = log_reg.predict_proba(X_new)

plt.plot(X_new, y_proba[:, 1], "g-", label="Iris-Versicolor Prob")
plt.plot(X_new, y_proba[:, 0], "b--", label="not Iris-Versicolor Prob")
plt.scatter(X, y, label='data')
plt.grid()

plt.legend(loc='best')
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# Now import all of the features in the dataset and try to fit a logistic regression on all the features and and classes.
# ##### Hint:
# 1. Make an object from LogisticRegression class in sklearn as following:
#
# `multiclass_logreg_obj = LogisticRegression(multi_class="multinomial",solver="lbfgs", C=10)`.
#
# `multiclass_logreg_obj` is just a name. It could be any (appropriate) name you like.

# %%
X = iris['data'][:,:2]
y = iris['target']

# %%
from sklearn.linear_model import LogisticRegression
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
# TODO 
# fit a multi class logistic regression to the dataset
multiclass_logreg_obj = LogisticRegression(multi_class="multinomial",solver="lbfgs", C=10)
multiclass_logreg_obj.fit(X,y)


# Step size in the mesh:
h = .02
# Light colors for decision boundaries plots:
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
# Bold colors for training points scatterplots:
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])


### Decision boundaries plotting:
# Generate the axis associated to the first feature: 
x_min = X[:, 0].min() - 1
x_max = X[:, 0].max() + 1

x_axis = np.arange(x_min, x_max, h)

# Generate the axis associated to the second feature:
y_min = X[:, 1].min() - 1
y_max = X[:, 1].max() + 1

y_axis = np.arange(y_min, y_max, h)


# Generate a meshgrid (2D grid) from the 2 axis:

x_grid, y_grid = np.meshgrid(x_axis, y_axis)
print(y_grid.shape)
# Vectorize the grids into column vectors:
x_grid_vectorized = x_grid.flatten()
x_grid_vectorized = np.expand_dims(x_grid_vectorized, axis=1)
y_grid_vectorized = y_grid.flatten()
y_grid_vectorized = np.expand_dims(y_grid_vectorized, axis=1)

# Concatenate the vectorized grids:
concat_grids = np.concatenate((x_grid_vectorized, y_grid_vectorized),axis=1)


# Predict concatenated features to get the decision boundaries:
decision_boundaries = multiclass_logreg_obj.predict(concat_grids)
# Reshape the decision boundaries into a 2D matrix:
decision_boundaries = decision_boundaries.reshape(x_grid.shape)
y_grid_vectorized
## Plot the decision boundaries:
#plt.figure()
plt.pcolormesh(x_grid,y_grid ,decision_boundaries , cmap=cmap_light)
# Overlay the training points:
plt.scatter(X[:, 0],X[:, 1] , c=y, cmap=cmap_bold, edgecolor='k', s=20)
# Out:
# (220, 280)
